# %%
import numpy as np
import pandas as pd

df = pd.read_csv("netflix1.csv")

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.drop(columns=['rating'])
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year   duration  \
# ...

# %%
len(df)
# Out:
# 8790

# %%
df['release_year'].dtypes
# Out:
# dtype('int64')

# %%
df['type'].dtype
# Out:
# dtype('O')

# %%
df['title'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
rating = np.random.randint(10, size=len(df))

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.drop(columns=['rating'])
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year   duration  \
# ...

# %%
rating = np.random.randint(10, size=len(df))

# %%
df.insert(8, 'rating', rating)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-cb88c573316d> in <cell line: 1>()
# ----> 1 df.insert(8, 'rating', rating)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert rating, already exists

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
overall_rating = np.random.randint(10, size=len(df))

# %%
df.insert(8, "overall ratings", overall_rating)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a843399f4d09> in <cell line: 1>()
# ----> 1 df.insert(8, "overall ratings", overall_rating)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert overall ratings, already exists

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  overall ratings  duration  \
# 0  United States  9/25/2021          2020  PG-13                3    90 min
# 1         France  9/24/2021          2021  TV-MA                4  1 Season
# 2  United States  9/24/2021          2021  TV-MA                2  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG                8    91 min
# 4  United States  9/24/2021          1993  TV-MA                5   125 min
#
#                                            listed_in
# ...

# %%
df.sample(20)
# Out:
#      show_id     type                                              title  \
# 2050   s2533    Movie                                         Dilan 1991
# 6723    s678  TV Show                                     Schitt's Creek
# 2651   s3483    Movie                                           Deliha 2
# 5266   s7222    Movie                        Koko: The Gorilla Who Talks
# 2363   s2996    Movie                                      Airplane Mode
# 2496   s3203    Movie                                    Wandering Stars
# 8105   s5246  TV Show                                 Star Trek: Voyager
# 7700   s3797  TV Show                    Hyper HardBoiled Gourmet Report
# 7553   s3465  TV Show                                  Engineering Girls
# 4254   s5959    Movie                                                  9
# 1769   s2122    Movie                                        Seventh Son
# 7230   s2433  TV Show                                              Alone
# ...

# %%
df['duration'].where(df['duration'] > "120 min")
# Out:
# 0          90 min
# 1             NaN
# 2             NaN
# 3          91 min
# 4         125 min
#           ...
# 8785    2 Seasons
# 8786    3 Seasons
# 8787          NaN
# 8788          NaN
# 8789          NaN
# Name: duration, Length: 8790, dtype: object

# %%
df.groupby('type')

# %%
df['type'].value_counts('Movie')
# Out:
# Movie      0.696928
# TV Show    0.303072
# Name: type, dtype: float64

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  overall ratings  duration  \
# 0  United States  9/25/2021          2020  PG-13                3    90 min
# 1         France  9/24/2021          2021  TV-MA                4  1 Season
# 2  United States  9/24/2021          2021  TV-MA                2  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG                8    91 min
# 4  United States  9/24/2021          1993  TV-MA                5   125 min
#
#                                            listed_in
# ...

# %%
df['director'].fillna('Unknown', inplace=True)

# %%
df.sample(30)
# Out:
#      show_id     type                                              title  \
# 1032   s1017    Movie                                        Delhi Belly
# 4118   s5750    Movie                       Bleach the Movie: Hell Verse
# 3490   s4826    Movie                                       Lust Stories
# 6499   s8760    Movie                             World's Weirdest Homes
# 159     s850    Movie  Sam Smith: Love Goes - Live at Abbey Road Studios
# 7392   s3029  TV Show                              The Ollie & Moon Show
# 4696   s6495    Movie                                         Class Rank
# 8538   s7236  TV Show                                     Krishna Balram
# 7319   s2793  TV Show                                                She
# 849     s766    Movie                                             Xtreme
# 7233   s2467  TV Show                    Mako Mermaids: An H2O Adventure
# 6336   s8559    Movie                                          The Witch
# ...

# %%
df.replace('Not Given', 'Unknown')
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre          Unknown
# 8786   s8798  TV Show                         Zak Storm          Unknown
# 8787   s8801  TV Show                Zindagi Gulzar Hai          Unknown
# 8788   s8784  TV Show                              Yoko          Unknown
# 8789   s8786  TV Show                               YOM          Unknown
#
#             country  date_added  release_year rating  overall ratings  \
# ...
